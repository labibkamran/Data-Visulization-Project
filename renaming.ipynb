# %%
import pandas as pd


# 1. ASER SCHOOL DATASET — COLUMN RENAME DICTIONARY


aser_school_rename = {
    "SYEAR": "survey_year",
    "AREA": "area_type",
    "VMAPID": "village_map_id",
    "RNAME": "province",
    "DNAME": "district",
    "VlgId": "village_id",
    "VlgCode": "village_code",
    "SID": "school_id",
    "STYPE": "school_type",

    "S006": "private_school_ownership",
    "S00": "class_range_from_to",
    "S00a": "class_range_other",
    "S001": "gender_type",
    "S002": "medium_of_instruction",
    "S002a": "medium_of_instruction_other",
    "S002Y": "year_established",
    "S007E": "enrollment_total",
    "S007P": "enrollment_present_today",

    "S03a1": "class2_multigrade",
    "S03b1": "class2_multigrade_with_class",
    "S03f1": "class2_learning_material",
    "S03d1": "class2_blackboard_available",
    "S03e1": "class2_textbooks_available",
    "S03c1": "class2_seating_place",

    "S03a2": "class8_multigrade",
    "S03b2": "class8_multigrade_with_class",
    "S03f2": "class8_learning_material",
    "S03d2": "class8_blackboard_available",
    "S03e2": "class8_textbooks_available",
    "S03c2": "class8_seating_place",

    "S004": "disability_any",

    # Visual
    "S004VB1": "disability_visual_boys_some",
    "S004VB2": "disability_visual_boys_lot",
    "S004VB3": "disability_visual_boys_none",
    "S004VG1": "disability_visual_girls_some",
    "S004VG2": "disability_visual_girls_lot",
    "S004VG3": "disability_visual_girls_none",

    # Hearing
    "S004HB1": "disability_hearing_boys_some",
    "S004HB2": "disability_hearing_boys_lot",
    "S004HB3": "disability_hearing_boys_none",
    "S004HG1": "disability_hearing_girls_some",
    "S004HG2": "disability_hearing_girls_lot",
    "S004HG3": "disability_hearing_girls_none",

    # Physical
    "S004PB1": "disability_physical_boys_some",
    "S004PB2": "disability_physical_boys_lot",
    "S004PB3": "disability_physical_boys_none",
    "S004PG1": "disability_physical_girls_some",
    "S004PG2": "disability_physical_girls_lot",
    "S004PG3": "disability_physical_girls_none",

    # Intellectual
    "S004IB1": "disability_intellectual_boys_some",
    "S004IB2": "disability_intellectual_boys_lot",
    "S004IB3": "disability_intellectual_boys_none",
    "S004IG1": "disability_intellectual_girls_some",
    "S004IG2": "disability_intellectual_girls_lot",
    "S004IG3": "disability_intellectual_girls_none",

    # Speech/Communication
    "S004SCRB1": "disability_speech_boys_some",
    "S004SCRB2": "disability_speech_boys_lot",
    "S004SCRB3": "disability_speech_boys_none",
    "S004SCRG1": "disability_speech_girls_some",
    "S004SCRG2": "disability_speech_girls_lot",
    "S004SCRG3": "disability_speech_girls_none",

    # Cognitive
    "S004COTB1": "disability_cognitive_boys_some",
    "S004COTB2": "disability_cognitive_boys_lot",
    "S004COTB3": "disability_cognitive_boys_none",
    "S004COTG1": "disability_cognitive_girls_some",
    "S004COTG2": "disability_cognitive_girls_lot",
    "S004COTG3": "disability_cognitive_girls_none",

    # Facilities
    "S004FR": "facility_ramp_available",
    "S004FT": "facility_accessible_toilet",
    "S004FHN": "facility_health_worker",
    "S004TSS": "facility_special_training_teacher",
    "S004ADHI": "facility_hearing_assistive_device",
    "S004TF": "facility_transport",

    # Infra S011
    "S011Ob1": "infra_boundary_wall",
    "S011Ob2": "infra_school_gate",
    "S011Ob3": "infra_playground",
    "S011Ob4": "infra_lighting",
    "S011Ob5": "infra_fans",
    "S011Ob6": "infra_drinking_water",
    "S011Ob7": "infra_clean_toilets",
    "S011Ob8": "infra_functional_toilets",
    "S011Ob9": "infra_handwashing",
    "S011Ob10": "infra_disability_toilet",
    "S011Ob11": "infra_library",
    "S011Ob12": "infra_science_lab",
    "S011Ob13": "infra_computer_lab",
    "S011Ob14": "infra_generator",
    "S011Ob15": "infra_office_room",
    "S011Ob16": "infra_classrooms",
    "S011Ob17": "infra_furniture",
    "S011Ob18": "infra_security",
    "S011Ob19": "infra_cctv",
    "S011Ob20": "infra_other",

    # Infra S012
    "S012Ob1": "infra_library_available",
    "S012Ob2": "infra_computer_lab_available",
    "S012Ob3": "infra_internet_available",
    "S012Ob4": "infra_firstaid_available",
    "S012Ob5": "infra_science_kit_available",
    "S012Ob6": "infra_sports_material_available",
    "S012Ob7": "infra_multimedia_available",
    "S012Ob8": "infra_art_material_available",
    "S012Ob11": "infra_roof_condition",
    "S012Ob12": "infra_classroom_condition",
    "S012Ob13": "infra_school_cleanliness",
    "S012Ob14": "infra_boundary_condition",
    "S012Ob15": "infra_furniture_condition",
    "S012Ob16": "infra_electricity_functional",

    # Teachers
    "S008TA": "teachers_total",
    "S008TP": "teachers_present_today",

    "S009b": "teacher_qualification_matric",
    "S009c": "teacher_qualification_intermediate",
    "S009d": "teacher_qualification_bachelors",
    "S009e": "teacher_qualification_masters",
    "S009f": "teacher_qualification_mphil",
    "S009g": "teacher_qualification_phd",
    "S009z": "teacher_qualification_other",

    "S010b": "teacher_professional_ptc",
    "S010c": "teacher_professional_ct",
    "S010d": "teacher_professional_bed",
    "S010e": "teacher_professional_med",
    "S010z": "teacher_professional_other",

    # SMC
    "S014h1": "smc_training_1",
    "S014h2": "smc_training_2",
    "S014h3": "smc_training_3",
    "S014h4": "smc_training_4",

    "S014a": "smc_active",
    "S014c": "smc_members_total",
    "S014d": "smc_female_members",
    "S014e": "smc_bank_balance",
    "S014f": "smc_teacher_attendance_monitoring",
    "S014g": "smc_last_meeting_date",

    # Water sources
    "S013a": "water_source_1",
    "S013b": "water_source_2",
    "S013c": "water_source_3",
    "S013d": "water_source_4",
    "S013e": "water_source_5",

    "SURID": "surveyor_id"
}


# 2. ASER CHILD DATASET — COLUMN RENAME DICTIONARY


aser_child_rename = {
    "Id": "child_id",
    "RNAME": "province",
    "PrvCode": "province_code",
    "DNAME": "district",
    "DstCode": "district_code",
    "VCODES": "village_code",

    "C03": "child_age",
    "C04": "child_gender",
    "C05": "schooling_status",
    "C06": "dropout_class",
    "C08": "dropout_reason",
    "C09": "never_enrolled_reason",
    "C10": "current_class",
    "C11": "institution_type",
    "C12": "attends_surveyed_school",
    "C07": "scholarship_received",
    "C13": "takes_tuition",
    "C14": "tuition_fee",

    "C15": "reading_level",
    "C16": "bonus_reading_q1",
    "B17": "bonus_reading_q2",
    "C18": "arithmetic_language",
    "C19": "arithmetic_level",
    "C23": "gk_q1_attempt",
    "C24": "gk_q2_attempt",
    "C25": "gk_q3_attempt",
    "C20": "english_word_reading",
    "C21": "english_sentence_reading",
    "C22": "english_comprehension",
    "C26a": "figure_identification_1",
    "C26b": "figure_identification_2",
    "C27": "object_naming",

    "PRID": "parent_id",
    "ICH01": "child_illness_1",
    "ICH02": "child_illness_2",
    "ICH03": "child_illness_3",
    "ICH05": "child_illness_5",

    "BasicVaccines": "vaccination_basic",
    "Allergies": "has_allergies",
    "C28": "child_available_for_testing",

    "Polio": "vaccine_polio",
    "DPT_HepB_Hib": "vaccine_dpt_hepb_hib",
    "Pneumococcal": "vaccine_pneumococcal",
    "Measles": "vaccine_measles",
    "BCG": "vaccine_bcg",

    "AREA": "area_type",
    "HHID": "household_id"
}

# %%
school_file = "/Users/robbannn/Desktop/SEM_5/DV_PROJECT/RAW_excel/ITAASER2023School (1).xlsx"
child_file = "/Users/robbannn/Desktop/SEM_5/DV_PROJECT/RAW_excel/ITAASER2023Child.xlsx"

# Read
df_school = pd.read_excel(school_file)
df_child = pd.read_excel(child_file)

# Rename
df_school.rename(columns=aser_school_rename, inplace=True)
df_child.rename(columns=aser_child_rename, inplace=True)

# Save
df_school.to_csv("aser_school_cleaned.csv", index=False)
df_child.to_csv("aser_child_cleaned.csv", index=False)

print("Column renaming completed ")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 5
#       2 child_file = "/Users/robbannn/Desktop/SEM_5/DV_PROJECT/RAW_excel/ITAASER2023Child.xlsx"
#       4 # Read
# ----> 5 df_school = pd.read_csv(school_file)
#       6 df_child = pd.read_csv(child_file)
#       8 # Rename
#
# ...
